# %% [markdown]
# # EXPLORATORY DATA ANALYSIS ON A DATASET

# %% [markdown]
# ## 1.	Data Cleaning and Preparation:

# %%
import pandas as pd
import numpy as np

# Load the dataset into a DataFrame
df = pd.read_csv(r"C:\Users\Lenovo\Desktop\Cardiotocographic.csv")
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
# Fill missing values with the mean of the column
df['LB'] = df['LB'].fillna(df['LB'].mean())

# %%
df.isnull().sum()
# Out:
# LB           0
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
# Drop rows with any missing values
df.dropna(inplace=True)

# %%
# Convert a column to numeric type
df['LB'] = pd.to_numeric(df['LB'], errors='coerce')
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %% [markdown]
# # Statistical Summary

# %%
import pandas as pd
import numpy as np

# Example dataset
data = pd.read_csv(r"C:\Users\Lenovo\Desktop\Cardiotocographic.csv")
df = pd.DataFrame(data)
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
# Summary statistics
summary = df.describe()
summary
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
# Calculate additional statistics
summary.loc['median'] = data.median()
summary.loc['IQR'] = data.quantile(0.75) - data.quantile(0.25)
# Display the summary
print(summary)
# Out:
#                  LB           AC           FM           UC           DL  \
# count   2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean     133.343598     0.003219     0.009894     0.004391     0.001895
# std       11.270154     0.004391     0.067540     0.003340     0.003343
# min       51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%      126.000000     0.000000     0.000000     0.001851     0.000000
# 50%      133.000000     0.001634     0.000000     0.004484     0.000000
# 75%      140.000000     0.005650     0.002567     0.006536     0.003289
# max      214.000000     0.038567     0.961268     0.030002     0.030769
# median   133.000000     0.001634     0.000000     0.004484     0.000000
# IQR       14.000000     0.005650     0.002567     0.004685     0.003289
#
#                  DS           DP         ASTV         MSTV         ALTV  \
# count   2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# ...

# %%
# Highlight interesting findings
interesting_findings = {
    'mean': data.mean(),
    'std_dev': data.std(),
    'median': data.median(),
    'IQR': data.quantile(0.75) - data.quantile(0.25)
}

print("\nInteresting Findings:")
for key, value in interesting_findings.items():
    print(f"{key}: {value}")
# Out:
# Interesting Findings:
# mean: LB          133.343598
# AC            0.003219
# FM            0.009894
# UC            0.004391
# DL            0.001895
# DS            0.000003
# DP            0.000175
# ASTV         46.995984
# MSTV          1.364378
# ALTV         10.285964
# MLTV          8.284887
# Width        70.429260
# Tendency      0.316371
# NSP           1.304507
# dtype: float64
# std_dev: LB          11.270154
# AC           0.004391
# FM           0.067540
# UC           0.003340
# DL           0.003343
# DS           0.000142
# DP           0.000840
# ASTV        18.813973
# MSTV         1.173632
# ALTV        21.205041
# MLTV         7.772858
# Width       42.931822
# Tendency     0.645622
# NSP          0.644619
# dtype: float64
# median: LB          133.000000
# AC            0.001634
# FM            0.000000
# UC            0.004484
# DL            0.000000
# DS            0.000000
# DP            0.000000
# ASTV         49.000000
# MSTV          1.200000
# ...

# %% [markdown]
# # Data Visualization:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
# Create histograms for numerical variables
data.hist(bins=30, figsize=(15, 10))
plt.suptitle('Histograms of Numerical Variables')
plt.show()

# %%
# Create boxplots for numerical variables
plt.figure(figsize=(8,4))
sns.boxplot(data=data)
plt.title('Boxplots of Numerical Variables')
plt.xticks(rotation=90)
plt.show()

# %%
# Bar charts for categorical variables
categorical_columns = ['NSP', 'Tendency'] 
for col in categorical_columns:
    plt.figure(figsize=(8,4))
    sns.countplot(x=col, data=data)
    plt.title(f'Bar Chart of {col}')
    plt.show()

# %%
# Pie charts for categorical variables
for col in categorical_columns:
    plt.figure(figsize=(4,4))
    data[col].value_counts().plot.pie(autopct='%1.1f%%')
    plt.title(f'Pie Chart of {col}')
    plt.ylabel('')
    plt.show()

# %%
# Scatter plots for exploring relationships
plt.figure(figsize=(4,4))
sns.scatterplot(x='LB', y='AC', data=data)  # Replace with actual numerical variable names
plt.title('Scatter Plot between Numerical LB and AC')
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(8,4))
correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Pair plots for deeper insights
sns.pairplot(data)
plt.title('Pair Plot of Variables')
plt.show()

# %%
 # Violin plots for deeper insights
plt.figure(figsize=(10, 6))
sns.violinplot(x='Tendency', y='AC', data=data)  # Replace with actual variable names
plt.title('Violin Plot of Numerical Var by Categorical Var')
plt.show()

# %% [markdown]
# # Pattern Recognition and Insights:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
# Verify the column names
print(df.columns)
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
# Identify correlations between variables
correlation_matrix = data.corr()
plt.figure(figsize=(8,8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix of Cardiotocographic Dataset')
plt.show()

# %%
# Plotting trends over time
plt.figure(figsize=(4,4))
sns.lineplot(data=data[['LB', 'AC']])  # Replace with actual variable names
plt.title('Trends of Variables Over Time')
plt.xlabel('Time')
plt.ylabel('Values')
plt.legend(['LB', 'AC'])
plt.show()

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### Consistent Baseline FHR:
# The baseline fetal heart rate (LB) remained fairly consistent across the dataset, indicating stable fetal heart conditions for the majority of observations.
#
# Symmetric Distributions: Several variables, such as accelerations (AC), displayed symmetric distributions, suggesting normal physiological variability.
#
# Low Variability in Uterine Contractions: The uterine contractions (UC) had a narrow interquartile range, indicating low variability and highlighting periods of consistent uterine activity.
#
# Correlations: The correlation heatmap unveiled relationships among variables, aiding in the understanding of how different measurements interact and influence one another.
#
# Time Series Insights: Time-based analysis, where applicable, showed trends and patterns, offering a dynamic view of fetal conditions over monitored periods.
#
# Visual Patterns: Advanced visualization techniques like pair plots and violin plots provided deeper insights into the data distribution and relationships between different variables.
